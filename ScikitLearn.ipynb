# %% [markdown]
# <a href="https://colab.research.google.com/github/DerinOgrenme2021/BurakHuseyinYanik/blob/main/ScikitLearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
import seaborn as sns; sns.set()
sns.pairplot(iris,hue="species",size=1.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris.shape
# Out:
# (150, 5)

# %%
x_iris=iris.drop("species",axis=1)
x_iris.shape
type(x_iris)
# Out:
# pandas.core.frame.DataFrame

# %%
y_iris=iris["species"]
y_iris.shape
# Out:
# (150,)

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(x_iris,y_iris)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_predicted=model.predict(x_iris)
from sklearn.metrics import accuracy_score
accuracy_score(y_predicted,y_iris)
# Out:
# 0.96

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
rng=np.random.RandomState(46)
x=10*rng.rand(100)
y=3*x-5+rng.randn(100)*5

# %%
x
# Out:
# array([7.83832351, 6.34833706, 2.49043092, 7.58075865, 3.13076936,
#        9.37237357, 0.42865448, 4.40867203, 9.1272229 , 4.55003919,
#        5.07934341, 0.84907955, 4.26349791, 7.4571696 , 8.67081396,
#        3.23665827, 1.04074397, 8.02108047, 3.94831949, 6.27768088,
#        0.35988544, 2.9990785 , 0.4765322 , 3.72211078, 2.62415196,
#        9.90526206, 3.95145348, 3.07539263, 2.21101136, 4.94025025,
#        0.5787519 , 2.89700041, 2.34950391, 9.63430415, 6.15673873,
#        8.62583969, 0.90085256, 1.48988902, 6.72574964, 9.78991925,
#        0.23223505, 9.07715691, 0.58051316, 7.55665434, 0.64602878,
#        2.55733424, 1.69607764, 1.95127297, 1.06556851, 5.207896  ,
#        0.06246276, 7.90605096, 1.38710924, 1.07145195, 4.29601164,
#        2.18972877, 8.35851729, 0.0587472 , 1.48322895, 6.98343843,
#        1.47609905, 8.70784536, 5.13986217, 4.24800256, 0.18968378,
#        4.94325926, 9.46624129, 3.45803428, 4.07328893, 8.28926431,
# ...

# %%
y
# Out:
# array([ 19.58864607,  11.93989856,   1.76866433,  12.56400183,
#          3.64018237,  13.08188578,  -3.7870345 ,   7.78160047,
#         29.41800704,   6.93934868,   6.54626035,  -5.73001663,
#          1.61494272,  23.5831131 ,  21.67373777,   7.78859624,
#          4.04215772,  15.97166296,   5.31838153,  15.46718739,
#         -3.0143665 ,  -0.78081311,  -4.60897254,   3.40264669,
#          4.34207423,  14.85420068,  12.23916094,  -0.86330084,
#         -1.37103141,   7.58624209,  -4.2951534 ,   1.66602336,
#          2.8880208 ,  22.11977086,  23.81872489,  19.73070824,
#         -0.88355195, -10.40137595,  14.92607307,  20.22714879,
#          5.58913491,  23.17720853,   0.89434999,  24.08637741,
#          7.12451223,  -7.09779092,   2.11335299,   3.09595342,
#          3.72573736,   8.38266596,  -6.53523471,  19.0285364 ,
#          2.51445866,   1.96717012,  -1.23979581,  -0.93752868,
#         20.54959751,  -6.79097371,   6.06463293,  18.80569025,
# ...

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression(fit_intercept=True)
x=x[:,np.newaxis]
x
# Out:
# array([[7.83832351],
#        [6.34833706],
#        [2.49043092],
#        [7.58075865],
#        [3.13076936],
#        [9.37237357],
#        [0.42865448],
#        [4.40867203],
#        [9.1272229 ],
#        [4.55003919],
#        [5.07934341],
#        [0.84907955],
#        [4.26349791],
#        [7.4571696 ],
#        [8.67081396],
#        [3.23665827],
#        [1.04074397],
#        [8.02108047],
#        [3.94831949],
#        [6.27768088],
#        [0.35988544],
#        [2.9990785 ],
#        [0.4765322 ],
#        [3.72211078],
#        [2.62415196],
#        [9.90526206],
#        [3.95145348],
#        [3.07539263],
#        [2.21101136],
#        [4.94025025],
#        [0.5787519 ],
#        [2.89700041],
#        [2.34950391],
#        [9.63430415],
#        [6.15673873],
#        [8.62583969],
#        [0.90085256],
#        [1.48988902],
#        [6.72574964],
#        [9.78991925],
#        [0.23223505],
#        [9.07715691],
#        [0.58051316],
# ...

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predicted=model.predict(x)
plt.scatter(x,y)
plt.plot(x,y_predicted)

print(model.predict([[6]]))
# Out:
# [13.21711735]
